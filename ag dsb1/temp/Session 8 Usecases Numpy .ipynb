# %% [markdown]
# ### 1) Write a Python program which accepts a list named : randomList = ['a', 0, 2]. Use exception handling using try-catch which.

# %%
randomList = ['a',0,2]
length = len(randomList)

for i in range(length):
    try:
        val = int(randomList[i])
        if val > 0:
            print("The entry is %d"% val)
            reciprocal = 1/val
            print("The reciprocal of %.1f is" % reciprocal)
        else:
            print("The entry is %d"%randomList[i])
            print("Oops! <class 'ZeroDivisionError'> occured.")
        
    except:
            print("The entry is %s "%randomList[i])
            print("Oops! <class 'ValueError'> occured.")
    print("Next entry.")
# Out:
# The entry is a
# Oops! <class 'ValueError'> occured.
# Next entry.
# The entry is 0
# Oops! <class 'ZeroDivisionError'> occured.
# Next entry.
# The entry is 2
# The reciprocal of 0.5 is
# Next entry.

# %% [markdown]
# ### 2) Array out of Bound Exception Write a Python program to give exception “Array Out of Bound” if the user wants to access the elements beyond the list size (use try and exce pt)

# %%
import numpy as np
arr=np.arange(4)
length=len(arr)
try:
    val=arr[length+1]
    print(val)
except:
    print("Array out of bound")
# Out:
# Array out of bound

# %% [markdown]
# ### 3) Write a python module script that contains fib2() method to calculate the Fibonacci series till 1000 and save it as fibo.py.

# %%
import fibo as fb
fb.fib2(1000)

# %% [markdown]
# ### 4) Write a python module script that contains ispalindrome() method to calculate the input string as palindrome string or not
# and save it as palindrome.py.

# %%
# palindrome or not 
def isPalindrome(s): 
      
    # Using predefined function to  
    # reverse to string print(s) 
    rev = ''.join(reversed(s)) 
  
    # Checking if both string are  
    # equal or not 
    if (s == rev): 
        return True
    return False
  
# main function 
s = "ajit"
ans = isPalindrome(s) 
  
if (ans): 
    print("Yes") 
else: 
    print("No")
# Out:
# No

# %% [markdown]
# ### 5) Write a program in Python with one class called Cipher. Within the constructor of this class, ask user for a string and storeit. Use a static variable, key to store a randomly generated integer between 1 and 50 inclusive. Implement two methods,encrypt and decrypt within this class. Encrypt generates and prints a cipher text using the user-entered string and the key and ecrypt generates decrypted string from ciphertext. The cipher only encrypts alpha and numeric (A-Z, a-z, 0-9). All Symbols,such as - , ; %, remain unencrypted. The cipher text can have special characters. Use generator expression to filter out alphaand numeric characters of the input string and to generate cipher text. Create an instance of this class, encrypt and decrypt back the user entered string.

# %%
import numpy as np
class Cipher:
    L2I = dict(zip("ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789",range(62)))
    I2L = dict(zip(range(62),"ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789"))
    
    def __init__(self,instr=""): 
        self.Instr=str(input("Enter the input string"))
        
    def encrypt(self,key):
        ciphertext = ""
        Instr=self.Instr
        for c in Instr:
            if c.isalnum(): 
                ciphertext += self.I2L[ (self.L2I[c] + key)%62 ]
            else: 
                ciphertext += c
        return ciphertext
    
    def decrypt(self,Enstr,key):
        plaintext2 = ""
        for c in Enstr:
            if c.isalnum(): plaintext2 += self.I2L[ (self.L2I[c] - key)%62]
            else: plaintext2 += c
        return plaintext2

k=np.random.randint(1,50,1)
key=k[0]
c=Cipher()
encryptstr=c.encrypt(key)
decryptstr=c.decrypt(encryptstr,key)
print("\n Input String is :\t"+c.Instr)
print("\nEncryption vaue of given string is :\t"+encryptstr)
print("\nDecryption vaue of given string is :\t"+decryptstr)

# %% [markdown]
# ### 6) Get Data from the following link:
# http://files.grouplens.org/datasets/movielens/ml-20m.zip
#
# #### We will be using the following files for this exercise:
#
# ##### ratings.csv : userId,movieId,rating, timestamp
#
# ##### tags.csv : userId,movieId, tag, timestamp
#
# ##### movies.csv : movieId, title, genres

# %% [markdown]
# ### Q1. Read the dataset using pandas.

# %%
import pandas as pd 
ratings = pd.read_csv(r"C:\Users\Admin\Desktop\Data Science Repo\Data Science Masters\V7\Session 8\ml-20m\ratings.csv") 
tags = pd.read_csv(r"C:\Users\Admin\Desktop\Data Science Repo\Data Science Masters\V7\Session 8\ml-20m\tags.csv") 
movies = pd.read_csv(r"C:\Users\Admin\Desktop\Data Science Repo\Data Science Masters\V7\Session 8\ml-20m\movies.csv")

# %% [markdown]
# ### Q2. Extract the first row from tags and print its type.

# %%
tags.head(1)
# Out:
#    userId  movieId          tag   timestamp
# 0      18     4141  Mark Waters  1240597180

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465564 entries, 0 to 465563
# Data columns (total 4 columns):
# userId       465564 non-null int64
# movieId      465564 non-null int64
# tag          465548 non-null object
# timestamp    465564 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 14.2+ MB

# %% [markdown]
# ### Q3. Extract row 0, 11, 2000 from tags DataFrame.

# %%
tags.take([0,11,2000])
# Out:
#       userId  movieId                tag   timestamp
# 0         18     4141        Mark Waters  1240597180
# 11        65     1783      noir thriller  1368149983
# 2000     910    68554  conspiracy theory  1368043943

# %% [markdown]
# ### Q4. Print index, columns of the DataFrame.

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %% [markdown]
# ### Q5. Calculate descriptive statistics for the 'ratings' column of the ratings DataFrame. Verify using describe().

# %%
print(ratings.describe())
# Out:
#              userId       movieId        rating     timestamp
# count  2.000026e+07  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00  1.100918e+09
# std    4.003863e+04  1.978948e+04  1.051989e+00  1.621694e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    3.439500e+04  9.020000e+02  3.000000e+00  9.667977e+08
# 50%    6.914100e+04  2.167000e+03  3.500000e+00  1.103556e+09
# 75%    1.036370e+05  4.770000e+03  4.000000e+00  1.225642e+09
# max    1.384930e+05  1.312620e+05  5.000000e+00  1.427784e+09

# %%
print(ratings.count())
# Out:
# userId       20000263
# movieId      20000263
# rating       20000263
# timestamp    20000263
# dtype: int64

# %%
print(ratings.mean())
# Out:
# userId       6.904587e+04
# movieId      9.041567e+03
# rating       3.525529e+00
# timestamp    1.100918e+09
# dtype: float64

# %%
print(ratings.std())
# Out:
# userId       4.003863e+04
# movieId      1.978948e+04
# rating       1.051989e+00
# timestamp    1.621694e+08
# dtype: float64

# %% [markdown]
# ### Q6. Filter out ratings with rating > 5

# %%
ratings[ratings.rating > 5]
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp]
# Index: []

# %% [markdown]
# ### Q7. Find how many null values, missing values are present. Deal with them. Print out how many rows have been modified.

# %%
# tags.isnull().values.ravel().sum()
tags.isnull().sum()
# Out:
# userId        0
# movieId       0
# tag          16
# timestamp     0
# dtype: int64

# %%
tags=tags.fillna(" ")

# %%
tags
# Out:
#         userId  movieId                                                tag  \
# 0           18     4141                                        Mark Waters
# 1           65      208                                          dark hero
# 2           65      353                                          dark hero
# 3           65      521                                      noir thriller
# 4           65      592                                          dark hero
# 5           65      668                                          bollywood
# 6           65      898                                   screwball comedy
# 7           65     1248                                      noir thriller
# 8           65     1391                                               mars
# 9           65     1617                                           neo-noir
# 10          65     1694                                              jesus
# ...

# %% [markdown]
# ### Q8. Filter out movies from the movies DataFrame that are of type 'Animation'

# %%
# movies['Animation' in movies.genres]
movies["Indexes"]= movies["genres"].str.find('Animation')
movies[movies.Indexes > 0]['title']
# Out:
# 0                                         Toy Story (1995)
# 12                                            Balto (1995)
# 360                                  Lion King, The (1994)
# 388             Secret Adventures of Tom Thumb, The (1993)
# 553                                 Pagemaster, The (1994)
# 582                                         Aladdin (1992)
# 604                                     Heavy Metal (1981)
# 624                         All Dogs Go to Heaven 2 (1996)
# 653                       James and the Giant Peach (1996)
# 664                                       Space Jam (1996)
# 697                                Oliver & Company (1988)
# 708      Wallace & Gromit: The Best of Aardman Animatio...
# 871      Land Before Time III: The Time of the Great Gi...
# 1011                                  Pete's Dragon (1977)
# 1013                            Alice in Wonderland (1951)
# 1197       Grand Day Out with Wallace and Gromit, A (1989)
# ...

# %% [markdown]
# ### Q9. Find the average rating of movies.¶

# %%
ratings['rating'].mean()
# Out:
# 3.5255285642993797

# %% [markdown]
# ### Q10. Perform an inner join of movies and tags based on movieId

# %%
merge= pd.merge(movies,tags,how='inner',on='movieId')
merge.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    Indexes  userId                                     tag   timestamp
# 0       10    1644                                 Watched  1417736680
# 1       10    1741                      computer animation  1183903155
# 2       10    1741                 Disney animated feature  1183933307
# 3       10    1741                         Pixar animation  1183934770
# 4       10    1741  TÃ©a Leoni does not star in this movie  1245093573

# %% [markdown]
# ### Q11. Print out the 5 movies that belong to the Comedy genre and have rating greater than 4.¶

# %%
movie_ratings= pd.merge(movies,ratings,how='inner',on='movieId')
movie_ratings.head(5)
# query('genres > 50 and C != 900')
movie_ratings.loc[(movie_ratings["genres"].str.find('Comedy')) & (movie_ratings["rating"] > 4), "title"].head(5)
# Out:
# 1     Toy Story (1995)
# 4     Toy Story (1995)
# 7     Toy Story (1995)
# 9     Toy Story (1995)
# 14    Toy Story (1995)
# Name: title, dtype: object

# %% [markdown]
# ### Q12. Split 'genres' into multiple columns.

# %%
movies['genres_split'] = movies['genres'].str.split('|')
movies['genres_split'].head(5)
# Out:
# 0    [Adventure, Animation, Children, Comedy, Fantasy]
# 1                       [Adventure, Children, Fantasy]
# 2                                    [Comedy, Romance]
# 3                             [Comedy, Drama, Romance]
# 4                                             [Comedy]
# Name: genres_split, dtype: object

# %% [markdown]
# ### Q13. Extract year from title e.g. (1995)

# %%
# movies['a'],movies['b'] = movies['title'].str.split('(', 1).str
#movies['title'].str.split('(')
#movies["title"].str.split("(", n = 1, expand = True) 
movies['ETL1']=movies["title"].str[-5:]
movies['ETL1'] = movies['ETL1'].str.replace(')','')

movies
# movies['year'].head()
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %% [markdown]
# ### Q14. Select rows based on timestamps later than 2015-02-01.¶

# %%
#timestamp Converting
ratings["NEWtimestamp"]=pd.to_datetime(ratings["timestamp"], unit='s')
ratings[ratings.NEWtimestamp>"2015-02-01"]
# Out:
#           userId  movieId  rating   timestamp        NEWtimestamp
# 3534          31        1     3.0  1424733487 2015-02-23 23:18:07
# 3535          31      110     5.0  1424733473 2015-02-23 23:17:53
# 3536          31      260     5.0  1424733433 2015-02-23 23:17:13
# 3537          31      364     3.0  1424844807 2015-02-25 06:13:27
# 3538          31      527     0.5  1424733598 2015-02-23 23:19:58
# 3539          31      588     3.0  1424842869 2015-02-25 05:41:09
# 3540          31      594     2.5  1424844811 2015-02-25 06:13:31
# 3541          31      616     4.0  1424844817 2015-02-25 06:13:37
# 3542          31     1196     5.0  1424733435 2015-02-23 23:17:15
# 3543          31     1197     3.0  1424734492 2015-02-23 23:34:52
# 3544          31     1207     0.5  1424734478 2015-02-23 23:34:38
# 3545          31     1210     5.0  1424733439 2015-02-23 23:17:19
# 3546          31     1214     0.5  1424733574 2015-02-23 23:19:34
# ...

# %% [markdown]
# ### Q15. Sort the tags DataFrame based on timestamp.¶

# %%
#timestamp Converting
tags['NEWtimestamp']=pd.to_datetime(tags['timestamp'], unit='s')
#Using .sort_value sorting dataframe
tags.sort_values(by='NEWtimestamp', ascending=False)
# Out:
#         userId  movieId                              tag   timestamp  \
# 339178  102853   115149                    russian mafia  1427771352
# 158780   46072     6058                      premonition  1427760764
# 158763   46072     3409                      premonition  1427760726
# 288375   87797      215                           Vienna  1427755801
# 290535   88044   106782                        profanity  1427754096
# 290527   88044   106782                            crime  1427753921
# 290526   88044   106782                           Amoral  1427753913
# 290531   88044   106782                       Jonah Hill  1427753849
# 290530   88044   106782                       inaccurate  1427753806
# 290528   88044   106782  Economically Illiterate Writers  1427753739
# 290533   88044   106782                Left-Wing Writers  1427753621
# 290532   88044   106782             Left-Wing Propaganda  1427753266
# 290529   88044   106782                             ENFP  1427753147
# ...
